# %% [markdown]
# # **Data Cleaning and Insight Generation from Survey Data**

# %% [markdown]
# **Author**: Yasmeen Rafique | Data Analytics Enthusiast
# 📅 July 2025 | 📍 Pakistan

# %% [markdown]
# ### 📌 Introduction
# This project dives into the kaggle survey 2017-2021 dataset ,data cleaning using Python and covering key trends with visualizations.

# %% [markdown]
# ### 🎯 Objective
# - Data cleaning
# - Categorical handling
# - Visualize patterns using Seaborn & Matplotlib

# %% [markdown]
# ### ⚙️ Tools & Libraries
# - Python
# - Pandas
# - Matplotlib, Seaborn

# %% [markdown]
# <h5 align ='center'><b>Data Exploration</b></h5>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('kaggle_survey_2017_2021.xlsx')
data
# Out:
#            - Time from Start to Finish (seconds)                           Q1  \
# 0       Year               Duration (in seconds)  What is your age (# years)?
# 1       2021                                 910                        50-54
# 2       2021                                 784                        50-54
# 3       2021                                 924                        22-24
# 4       2021                                 575                        45-49
# ...      ...                                 ...                          ...
# 106297  2017                                 NaN                        22-24
# 106298  2017                                 NaN                        25-29
# 106299  2017                                 NaN                        25-29
# 106300  2017                                 NaN                          NaN
# 106301  2017                                 NaN                        25-29
#
# ...

# %%
data.head()
# Out:
#       - Time from Start to Finish (seconds)                           Q1  \
# 0  Year               Duration (in seconds)  What is your age (# years)?
# 1  2021                                 910                        50-54
# 2  2021                                 784                        50-54
# 3  2021                                 924                        22-24
# 4  2021                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# ...

# %%
data.tail()
# Out:
#            - Time from Start to Finish (seconds)     Q1      Q2         Q3  \
# 106297  2017                                 NaN  22-24  Female      Other
# 106298  2017                                 NaN  25-29    Male  Indonesia
# 106299  2017                                 NaN  25-29  Female     Taiwan
# 106300  2017                                 NaN    NaN  Female  Singapore
# 106301  2017                                 NaN  25-29    Male      Japan
#
#                                                        Q4          Q5  \
# 106297                                    Master's degree         NaN
# 106298                                  Bachelor's degree  Programmer
# 106299                                                NaN         NaN
# 106300                             I prefer not to answer         NaN
# 106301  I did not complete any formal education past h...  Programmer
#
#                       Q6 Q7_Part_1 Q7_Part_2  ... Q38_B_Part_1 Q38_B_Part_2  \
# ...

# %%
data.shape
# Out:
# (106302, 293)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106302 entries, 0 to 106301
# Columns: 293 entries, - to Q38_B_OTHER
# dtypes: object(293)
# memory usage: 237.6+ MB

# %%
data.describe()
# Out:
#              -  Time from Start to Finish (seconds)      Q1      Q2      Q3  \
# count   106302                                89586  105857  106207  106181
# unique       6                                11716      12      10      78
# top       2021                                  498   25-29    Male   India
# freq     25973                                  107   23748   49178   25192
#
#                        Q4       Q5         Q6 Q7_Part_1 Q7_Part_2  ...  \
# count              103319    99088      92786     65943     20885  ...
# unique                 13       36         21         2         2  ...
# top     Masterâ€™s degree  Student  3-5 years    Python         R  ...
# freq                37395    21242      15995     65942     20884  ...
#
#         Q38_B_Part_1        Q38_B_Part_2 Q38_B_Part_3          Q38_B_Part_4  \
# count           2212                2761         1128                  1022
# ...

# %% [markdown]
# <h4 align = 'center'><b>Data Cleaning</b></h4>

# %%
print(data.isnull().sum())
# Out:
# -                                           0
# Time from Start to Finish (seconds)     16716
# Q1                                        445
# Q2                                         95
# Q3                                        121
#                                         ...
# Q38_B_Part_6                           105015
# Q38_B_Part_7                           105084
# Q38_B_Part_9                           105116
# Q38_B_Part_11                          106301
# Q38_B_OTHER                            105673
# Length: 293, dtype: int64

# %%
data.dropna(axis=1,how='all',inplace=True)

# %%
data.dropna(thresh=5,inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.columns = data.columns.str.strip().str.lower().str.replace(" ", "_").str.replace(r"[^a-z0-9_]", "", regex=True)

# %% [markdown]
# <h5 align = 'center'><b> Encode Categorical Data</b><h5>

# %%
education_map = {
    "Doctoral degree": 4,
    "Master’s degree": 3,
    "Bachelor’s degree": 2,
    "Some college/university study without earning a degree": 1,
    "I prefer not to answer": 0,
    "None": 0
}

data['education_encoded'] = data['q4'].map(education_map)

# %%
data
# Out:
#              time_from_start_to_finish_seconds                           q1  \
# 0       Year             Duration (in seconds)  What is your age (# years)?
# 1       2021                               910                        50-54
# 2       2021                               784                        50-54
# 3       2021                               924                        22-24
# 4       2021                               575                        45-49
# ...      ...                               ...                          ...
# 106290  2017                               NaN                        25-29
# 106295  2017                               NaN                        30-34
# 106297  2017                               NaN                        22-24
# 106298  2017                               NaN                        25-29
# 106301  2017                               NaN                        25-29
#
#                                             q2  \
# ...

# %% [markdown]
#  <h5 align = 'center'><b>Insight Generation</b></h5>

# %% [markdown]
# ##### **Top 5 Countries by Respondents**

# %%
data['q3'].value_counts().head(5)
# Out:
# q3
# India                       23911
# United States of America    12682
# Other                        5505
# China                        3502
# Russia                       3287
# Name: count, dtype: int64

# %% [markdown]
# ##### **Most Used Programming Languages**

# %%
language_cols = [col for col in data.columns if 'q7_part' in col]
data_lang = data[language_cols]
data_lang = data_lang.apply(pd.Series.value_counts).sum(axis=1).sort_values(ascending=False)
data_lang.head(5)
# Out:
# Python    65942.0
# SQL       33090.0
# R         20884.0
# Java      14402.0
# C++       11618.0
# dtype: float64

# %% [markdown]
# ##### **Salary Range by Education Level**

# %%
data[['q4', 'q25']].groupby('q4')['q25'].value_counts().unstack().fillna(0)
# Out:
# q25                                                 $0-999  $500,000-999,999  \
# q4
# Bachelorâ€™s degree                                 2714.0               6.0
# Doctoral degree                                      702.0               8.0
# I prefer not to answer                               204.0               1.0
# Masterâ€™s degree                                   2609.0              12.0
# No formal education past high school                 122.0               1.0
# Professional degree                                  162.0               0.0
# Professional doctorate                                58.0               2.0
# Some college/university study without earning a...   439.0               2.0
# What is the highest level of formal education t...     0.0               0.0
#
# q25                                                 0-10,000  1,000-1,999  \
# q4
# Bachelorâ€™s degree                                   1788.0        672.0
# ...

# %% [markdown]
# <h5 align = 'center'><b>Visualization</b></h5>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# <h5><b>Top 5 Programming Languages</b></h5>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar plot for top 5 languages
plt.figure(figsize=(10, 6))
sns.barplot(x=data_lang.head(5).values, y=data_lang.head(5).index, palette='viridis')
plt.title("Top 5 Programming Languages (2017–2021)")
plt.xlabel("Number of Users")
plt.ylabel("Programming Language")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5><b>Education Level Distribution</b></h5>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='education_encoded', data=data, palette='magma', order=sorted(data['education_encoded'].dropna().unique(), reverse=True))
plt.title("Education Level Distribution")
plt.xlabel("Count")
plt.ylabel("Education Level Code (0=Low, 4=High)")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5><b>Programming Language Usage by Education Level</b></h5>

# %%
# Melt language columns to long format for grouping
data_lang_melted = data[language_cols + ['education_encoded']].melt(id_vars='education_encoded', value_name='Language').dropna()

plt.figure(figsize=(12, 6))
sns.countplot(data=data_lang_melted, x='Language', hue='education_encoded', order=data_lang_melted['Language'].value_counts().index[:5])
plt.title("Top 5 Language Usage by Education Level")
plt.xlabel("Programming Language")
plt.ylabel("Count")
plt.legend(title="Education Level")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Insights and Key Findings

# %% [markdown]
# - Python consistently dominated as the top programming language, followed by SQL, R, and C/C++, confirming its relevance in data science and ML roles.
# - Most respondents held a Master’s or Bachelor’s degree, showing the importance of formal education in this field.
# - Users with higher education levels showed more diverse language usage, likely due to broader exposure and professional demands.

# %% [markdown]
# #### ✅ Conclusion
# This analysis reflects the evolving trends in the data science community from 2017 to 2021. It highlights that:
#
# - Python remains the most crucial language, valued by professionals of all educational backgrounds.
# - Education level influences the depth and diversity of tool usage.
# - The Kaggle community is primarily composed of well-educated professionals, reinforcing the competitive nature of the data science field.

# %% [markdown]
# ## 🙋‍♀️ About Me
#
# I'm Yasmeen Rafique, a Data Analytics passionate about storytelling with data, automation, and building impactful things in data field.
# Connect with me on [LinkedIn](www.linkedin.com/in/yasmeen-rafique) or check out more projects on [GitHub](https://github.com/Yasmeenrafique).
